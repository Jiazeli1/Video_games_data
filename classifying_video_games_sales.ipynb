# %%
import pandas as pd

# %%
path = 'vgsales.csv'
vgsales = pd.read_csv(path)

# %%
vgsales
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
Genre = vgsales.Genre

# %%
Genre
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
Name = vgsales.Name

# %%
Name
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %%
Name[0]
# Out:
# 'Wii Sports'

# %%
Publisher = vgsales.Publisher

# %%
Publisher
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16598, dtype: object

# %%
Publisher
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16598, dtype: object

# %%
Publisher[0]
# Out:
# 'Nintendo'

# %%
len(vgsales.Publisher.unique())
# Out:
# 579

# %%
1/579
# Out:
# 0.0017271157167530224

# %%
from stop_words import get_stop_words

def Name_features(Name):
#    name = Name.lower()
#    words = Name.split()
#    keywords= [x for x in words if x not in get_stop_words('english')]
    if len(Name) < 1:
        Name.append('Nothing')
    return{'first_Name':Name}

# %%
#def Name_features(Name):
    #return {'first_name': Name[0], 'second_name': Name[1]}

# %%
features_and_labels = zip(vgsales.Name, vgsales.Publisher)

# %%
features_and_labels

# %%
feature_sets = [ (Name_features(Name), Publisher) for Name, Publisher in features_and_labels]
feature_sets
# Out:
# [({'first_Name': 'Wii Sports'}, 'Nintendo'),
#  ({'first_Name': 'Super Mario Bros.'}, 'Nintendo'),
#  ({'first_Name': 'Mario Kart Wii'}, 'Nintendo'),
#  ({'first_Name': 'Wii Sports Resort'}, 'Nintendo'),
#  ({'first_Name': 'Pokemon Red/Pokemon Blue'}, 'Nintendo'),
#  ({'first_Name': 'Tetris'}, 'Nintendo'),
#  ({'first_Name': 'New Super Mario Bros.'}, 'Nintendo'),
#  ({'first_Name': 'Wii Play'}, 'Nintendo'),
#  ({'first_Name': 'New Super Mario Bros. Wii'}, 'Nintendo'),
#  ({'first_Name': 'Duck Hunt'}, 'Nintendo'),
#  ({'first_Name': 'Nintendogs'}, 'Nintendo'),
#  ({'first_Name': 'Mario Kart DS'}, 'Nintendo'),
#  ({'first_Name': 'Pokemon Gold/Pokemon Silver'}, 'Nintendo'),
#  ({'first_Name': 'Wii Fit'}, 'Nintendo'),
#  ({'first_Name': 'Wii Fit Plus'}, 'Nintendo'),
#  ({'first_Name': 'Kinect Adventures!'}, 'Microsoft Game Studios'),
#  ({'first_Name': 'Grand Theft Auto V'}, 'Take-Two Interactive'),
#  ({'first_Name': 'Grand Theft Auto: San Andreas'}, 'Take-Two Interactive'),
# ...

# %%
import random
random.shuffle(feature_sets)

# %%
len(feature_sets)
# Out:
# 16598

# %%
16598* .8
# Out:
# 13278.400000000001

# %%
training_set = feature_sets[:13278]
testing_set = feature_sets[13278:]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.classify(Name_features(('Sonic Mega Collection Plus')))
# Out:
# 'Sega'

# %%
print(nltk.classify.accuracy(classifier, testing_set))
# Out:
# 0.27740963855421685

# %%
classifier.show_most_informative_features(77)
# Out:
# Most Informative Features
#               first_Name = 'Terraria'     505 Ga : Unknow =      4.3 : 1.0
#               first_Name = 'Madden NFL 07' Electr : Unknow =      4.2 : 1.0
#               first_Name = 'Ghostbusters: The Video Game'  Atari : Sony C =      3.8 : 1.0
#               first_Name = 'DiRT 2'       Codema : Sony C =      3.3 : 1.0
#               first_Name = 'Brunswick Pro Bowling' 505 Ga : Crave  =      2.9 : 1.0
#               first_Name = 'Dead or Alive 5' Tecmo  : Ubisof =      2.8 : 1.0
#               first_Name = 'Rock Band 2'  MTV Ga : Electr =      2.8 : 1.0
#               first_Name = 'WRC: FIA World Rally Championship' Black  : Sony C =      2.6 : 1.0
#               first_Name = 'Madden NFL 2002' Electr : Unknow =      2.5 : 1.0
#               first_Name = 'Minecraft'    Micros : Sony C =      2.5 : 1.0
#               first_Name = 'Major League Baseball 2K7'  Spike : Take-T =      2.5 : 1.0
# ...
